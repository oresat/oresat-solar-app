# %%
import re

file = open("/home/hx3d/jupyter/psas/regex_test.txt", "r")
text = file.read()
text2 = """
hello I like beans
1 2v3v 4 5
hello 1 like beans
balls
wampa wampa do do
"""
print(text)

regex = r"(\d)"
# print(text2[10])
match = re.findall(regex, text)
print(match)
# print(match.groups())
# Out:
# hello I like beans
# 1 2v3v 4 5
# hello 1 like beans
# balls
# wampa wampa do do
# ['1', '2', '3', '4', '5', '1']
